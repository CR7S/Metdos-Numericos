# %%
import math
gra=9.8
masa=68.1
tiempo=10
velocidad=40
valor_menor=12
valor_mayor=16
variable_estado=1
variable_comprobacion=False
contador=0
def f(coeficiente):
    return ((gra*masa/coeficiente)*(1-math.exp(-(coeficiente/masa)*tiempo)))-velocidad
def fxr(valor_mayor,valor_menor):
    return (valor_mayor+valor_menor)/2
if((f(valor_mayor)*f(valor_menor))<0):
    resultado=fxr(valor_mayor,valor_menor)
print valor_mayor," ",valor_menor," ",resultado
aux=0
while((f(valor_mayor)*f(valor_menor))!=0):
    if((f(valor_mayor)*f(valor_menor))<0):
        valor_menor=resultado
        resultado=fxr(valor_mayor,valor_menor)
        print valor_mayor," ",valor_menor," ",resultado
    else:
        if((f(valor_mayor)*f(valor_menor))>0):
            valor_mayor=resultado
            resultado=fxr(valor_mayor,valor_menor)
            print valor_mayor," ",valor_menor," ",resultado

x=12        
i=0
# Out:
# 16   12   14
# 16   14   15
# 16   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# 15   15   15
# ...
